# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df1['A'].max()
# Out:
# 3.4122362677697287

# %%
df1['A'].min()
# Out:
# -3.693201134879104

# %%
df1['A'].hist(bins=50)

# %%
data =df1[(df1['A']>=2) &(df1['A']<=3)]

# %%
data
# Out:
#                    A         B         C         D
# 2000-05-20  2.768111  0.380201  0.862157 -1.748788
# 2000-08-21  2.158409 -1.354801  1.316140  0.243924
# 2000-10-02  2.120693 -0.544170 -1.207810  0.778640
# 2001-02-15  2.101270  0.474559  0.902040 -1.546444
# 2001-02-20  2.014016 -0.516919  0.208224 -0.583352
# 2001-05-08  2.183147 -0.912370  0.726969 -0.991265
# 2001-05-29  2.213289 -1.065768  0.920545  0.140741
# 2001-06-11  2.100026  1.924576 -0.576087 -0.610919
# 2001-07-18  2.527888 -0.490426 -0.696252 -0.714083
# 2001-10-31  2.226214  0.650774 -1.405790  0.532482
# 2001-11-16  2.105826 -0.061556  0.661245  1.444373
# 2002-03-29  2.376208 -1.464279  0.511634  2.151667
# 2002-08-07  2.309809 -0.131540 -0.737028 -0.655841
# 2002-08-11  2.883919  1.626665  1.020558  0.921622

# %%
data['A'].hist(bins=30)

# %%
mydata = pd.read_csv('Book1.csv')

# %%
mydata

# %%
mydata['Col'].hist(bins=20)

# %%
# pandas have may plot

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot.hist()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.area()

# %%
df2.plot.bar()
#here it use the index as x

# %%
df2.plot.bar(stacked=True)

# %%
#df1.plot.line(x='df1.index',y='B')
df1.plot.line(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B')

# %%
df2.plot.box()

# %%
df2.plot.density()
